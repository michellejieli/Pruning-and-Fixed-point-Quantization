# %% [markdown]
# ### Lab2 (a) Model preperation

# %%
from resnet20 import ResNetCIFAR
from train_util import train, finetune, test
import torch
import numpy as np

import time

import torchvision.transforms as transforms
import torchvision
import torch.nn as nn
import torch.optim as optim

from FP_layers import *

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
net = ResNetCIFAR(num_layers=20, Nbits=None)
net = net.to(device)

# %%
# Load the best weight paramters
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3231, Test accuracy=0.9151

# %% [markdown]
# ### Lab2 (b) Prune by percentage

# %%
def prune_by_percentage(layer, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # Convert the weight of "layer" to numpy array
    weight = layer.weight.data.cpu().numpy()
    # Compute the q-th percentile of the abs of the converted array
    threshold = np.percentile(np.abs(weight), q)
    # Generate a binary mask same shape as weight to decide which element to prune
    mask = np.abs(weight) > threshold
    # Convert mask to torch tensor and put on GPU
    mask = torch.from_numpy(mask).float().to(device)
    # Multiply the weight by mask to perform pruning
    layer.weight.data.mul_(mask)
    pass

# %%
# try q = 0.4, 0.6, 0.8
q_lst = [40,60,80]
net.load_state_dict(torch.load("pretrained_model.pt"))

for q in q_lst:
    print("q:",str(q))
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # change q value
            prune_by_percentage(layer, q)
            # Optional: Check the sparsity you achieve in each layer
            print(name, layer.weight.data.cpu().numpy().size - np.count_nonzero(layer.weight.data.cpu().numpy()))
            # Convert the weight of "layer" to numpy array
            np_weight = layer.weight.data.cpu().numpy()
            # Count number of zeros
            zeros = np.count_nonzero(np_weight == 0) 
            # Count number of parameters
            total = np_weight.size
            # Print sparsity
            print('Sparsity of '+name+': '+str(zeros/total))

    test(net)
# Out:
# q: 40
# head_conv.0.conv 173
# Sparsity of head_conv.0.conv: 0.40046296296296297
# body_op.0.conv1.0.conv 922
# Sparsity of body_op.0.conv1.0.conv: 0.4001736111111111
# body_op.0.conv2.0.conv 922
# Sparsity of body_op.0.conv2.0.conv: 0.4001736111111111
# body_op.1.conv1.0.conv 922
# Sparsity of body_op.1.conv1.0.conv: 0.4001736111111111
# body_op.1.conv2.0.conv 922
# Sparsity of body_op.1.conv2.0.conv: 0.4001736111111111
# body_op.2.conv1.0.conv 922
# Sparsity of body_op.2.conv1.0.conv: 0.4001736111111111
# body_op.2.conv2.0.conv 922
# Sparsity of body_op.2.conv2.0.conv: 0.4001736111111111
# body_op.3.conv1.0.conv 1843
# Sparsity of body_op.3.conv1.0.conv: 0.3999565972222222
# body_op.3.conv2.0.conv 3687
# Sparsity of body_op.3.conv2.0.conv: 0.4000651041666667
# body_op.4.conv1.0.conv 3687
# Sparsity of body_op.4.conv1.0.conv: 0.4000651041666667
# body_op.4.conv2.0.conv 3687
# Sparsity of body_op.4.conv2.0.conv: 0.4000651041666667
# body_op.5.conv1.0.conv 3687
# Sparsity of body_op.5.conv1.0.conv: 0.4000651041666667
# body_op.5.conv2.0.conv 3687
# Sparsity of body_op.5.conv2.0.conv: 0.4000651041666667
# body_op.6.conv1.0.conv 7373
# Sparsity of body_op.6.conv1.0.conv: 0.4000108506944444
# body_op.6.conv2.0.conv 14746
# Sparsity of body_op.6.conv2.0.conv: 0.4000108506944444
# body_op.7.conv1.0.conv 14746
# Sparsity of body_op.7.conv1.0.conv: 0.4000108506944444
# body_op.7.conv2.0.conv 14746
# Sparsity of body_op.7.conv2.0.conv: 0.4000108506944444
# body_op.8.conv1.0.conv 14746
# Sparsity of body_op.8.conv1.0.conv: 0.4000108506944444
# body_op.8.conv2.0.conv 14746
# Sparsity of body_op.8.conv2.0.conv: 0.4000108506944444
# final_fc.linear 256
# Sparsity of final_fc.linear: 0.4
# Files already downloaded and verified
# Test Loss=0.4311, Test accuracy=0.8874
# q: 60
# head_conv.0.conv 259
# Sparsity of head_conv.0.conv: 0.5995370370370371
# body_op.0.conv1.0.conv 1382
# Sparsity of body_op.0.conv1.0.conv: 0.5998263888888888
# body_op.0.conv2.0.conv 1382
# Sparsity of body_op.0.conv2.0.conv: 0.5998263888888888
# body_op.1.conv1.0.conv 1382
# Sparsity of body_op.1.conv1.0.conv: 0.5998263888888888
# body_op.1.conv2.0.conv 1382
# Sparsity of body_op.1.conv2.0.conv: 0.5998263888888888
# body_op.2.conv1.0.conv 1382
# Sparsity of body_op.2.conv1.0.conv: 0.5998263888888888
# body_op.2.conv2.0.conv 1382
# Sparsity of body_op.2.conv2.0.conv: 0.5998263888888888
# body_op.3.conv1.0.conv 2765
# Sparsity of body_op.3.conv1.0.conv: 0.6000434027777778
# body_op.3.conv2.0.conv 5530
# Sparsity of body_op.3.conv2.0.conv: 0.6000434027777778
# body_op.4.conv1.0.conv 5530
# Sparsity of body_op.4.conv1.0.conv: 0.6000434027777778
# body_op.4.conv2.0.conv 5530
# Sparsity of body_op.4.conv2.0.conv: 0.6000434027777778
# body_op.5.conv1.0.conv 5530
# Sparsity of body_op.5.conv1.0.conv: 0.6000434027777778
# body_op.5.conv2.0.conv 5530
# Sparsity of body_op.5.conv2.0.conv: 0.6000434027777778
# body_op.6.conv1.0.conv 11059
# Sparsity of body_op.6.conv1.0.conv: 0.5999891493055556
# body_op.6.conv2.0.conv 22118
# Sparsity of body_op.6.conv2.0.conv: 0.5999891493055556
# body_op.7.conv1.0.conv 22118
# Sparsity of body_op.7.conv1.0.conv: 0.5999891493055556
# body_op.7.conv2.0.conv 22118
# Sparsity of body_op.7.conv2.0.conv: 0.5999891493055556
# body_op.8.conv1.0.conv 22118
# Sparsity of body_op.8.conv1.0.conv: 0.5999891493055556
# body_op.8.conv2.0.conv 22118
# Sparsity of body_op.8.conv2.0.conv: 0.5999891493055556
# final_fc.linear 384
# Sparsity of final_fc.linear: 0.6
# Files already downloaded and verified
# Test Loss=1.0955, Test accuracy=0.7226
# q: 80
# head_conv.0.conv 345
# Sparsity of head_conv.0.conv: 0.7986111111111112
# body_op.0.conv1.0.conv 1843
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# body_op.0.conv2.0.conv 1843
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# body_op.1.conv1.0.conv 1843
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# body_op.1.conv2.0.conv 1843
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# body_op.2.conv1.0.conv 1843
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# body_op.2.conv2.0.conv 1843
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# body_op.3.conv1.0.conv 3686
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# body_op.3.conv2.0.conv 7373
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# body_op.4.conv1.0.conv 7373
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# body_op.4.conv2.0.conv 7373
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# body_op.5.conv1.0.conv 7373
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# body_op.5.conv2.0.conv 7373
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# body_op.6.conv1.0.conv 14745
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# body_op.6.conv2.0.conv 29491
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# body_op.7.conv1.0.conv 29491
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# body_op.7.conv2.0.conv 29491
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# body_op.8.conv1.0.conv 29491
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# body_op.8.conv2.0.conv 29491
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# final_fc.linear 512
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=6.3235, Test accuracy=0.1003

# %% [markdown]
# ### Lab2 (c) Finetune pruned model

# %%
def finetune_after_prune(net, trainloader, criterion, optimizer, prune=True):
    """
    Finetune the pruned model for a single epoch
    Make sure pruned weights are kept as zero
    """
    # Build a dictionary for the nonzero weights
    weight_mask = {}
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Your code here: generate a mask in GPU torch tensor to have 1 for nonzero element and 0 for zero element 
            weight_mask[name] = torch.from_numpy(np.abs(layer.weight.data.cpu().numpy()) > 0).float().to(device)
    
    global_steps = 0
    train_loss = 0
    correct = 0
    total = 0
    start = time.time()
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        
        if prune:
            for name,layer in net.named_modules():
                if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                    # Your code here: Use weight_mask to make sure zero elements remains zero
                    layer.weight.data = layer.weight.data.mul_(weight_mask[name])
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        global_steps += 1

        if global_steps % 50 == 0:
            end = time.time()
            batch_size = 256
            num_examples_per_second = 50 * batch_size / (end - start)
            print("[Step=%d]\tLoss=%.4f\tacc=%.4f\t%.1f examples/second"
                 % (global_steps, train_loss / (batch_idx + 1), (correct / total), num_examples_per_second))
            start = time.time()

# %%
# Get pruned model
net.load_state_dict(torch.load("pretrained_model.pt"))
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        prune_by_percentage(layer, q=80.0)

# Training setup, do not change
batch_size=256
lr=0.002
reg=1e-4

print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=16)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=2)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.875, weight_decay=reg, nesterov=False)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Model finetuning
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    net.train()
    finetune_after_prune(net, trainloader, criterion, optimizer)
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))

    if val_acc > best_acc:
        best_acc = val_acc
        print("Saving...")
        torch.save(net.state_dict(), "net_after_finetune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.9871	acc=0.6843	3646.7 examples/second
# [Step=100]	Loss=0.8052	acc=0.7383	6326.0 examples/second
# [Step=150]	Loss=0.7221	acc=0.7631	6432.9 examples/second
# Test Loss=0.5583, Test acc=0.8190
# Saving...
#
# Epoch: 1
# [Step=50]	Loss=0.4642	acc=0.8431	4185.5 examples/second
# [Step=100]	Loss=0.4560	acc=0.8469	5489.9 examples/second
# [Step=150]	Loss=0.4443	acc=0.8509	5323.7 examples/second
# Test Loss=0.4871, Test acc=0.8394
# Saving...
#
# Epoch: 2
# [Step=50]	Loss=0.3950	acc=0.8648	3748.7 examples/second
# [Step=100]	Loss=0.3916	acc=0.8664	5102.9 examples/second
# [Step=150]	Loss=0.3893	acc=0.8671	4968.4 examples/second
# Test Loss=0.4558, Test acc=0.8509
# Saving...
#
# Epoch: 3
# [Step=50]	Loss=0.3767	acc=0.8706	3752.1 examples/second
# [Step=100]	Loss=0.3678	acc=0.8732	5580.7 examples/second
# [Step=150]	Loss=0.3654	acc=0.8742	5691.2 examples/second
# Test Loss=0.4352, Test acc=0.8580
# Saving...
#
# Epoch: 4
# [Step=50]	Loss=0.3380	acc=0.8827	3818.9 examples/second
# [Step=100]	Loss=0.3417	acc=0.8839	5205.4 examples/second
# [Step=150]	Loss=0.3411	acc=0.8841	5473.1 examples/second
# Test Loss=0.4225, Test acc=0.8601
# Saving...
#
# Epoch: 5
# [Step=50]	Loss=0.3264	acc=0.8892	3857.2 examples/second
# [Step=100]	Loss=0.3282	acc=0.8888	5692.0 examples/second
# [Step=150]	Loss=0.3283	acc=0.8881	6154.2 examples/second
# Test Loss=0.4133, Test acc=0.8638
# Saving...
#
# Epoch: 6
# [Step=50]	Loss=0.3232	acc=0.8901	3970.5 examples/second
# [Step=100]	Loss=0.3097	acc=0.8938	5698.1 examples/second
# [Step=150]	Loss=0.3125	acc=0.8930	5093.9 examples/second
# Test Loss=0.4058, Test acc=0.8665
# Saving...
#
# Epoch: 7
# [Step=50]	Loss=0.2980	acc=0.8976	3477.9 examples/second
# [Step=100]	Loss=0.3025	acc=0.8960	5684.6 examples/second
# [Step=150]	Loss=0.3022	acc=0.8966	5352.2 examples/second
# Test Loss=0.3972, Test acc=0.8664
#
# Epoch: 8
# [Step=50]	Loss=0.2932	acc=0.8976	3741.6 examples/second
# [Step=100]	Loss=0.2950	acc=0.8986	5766.2 examples/second
# [Step=150]	Loss=0.2943	acc=0.8993	6235.6 examples/second
# Test Loss=0.3947, Test acc=0.8695
# Saving...
#
# Epoch: 9
# [Step=50]	Loss=0.2802	acc=0.9043	3870.8 examples/second
# [Step=100]	Loss=0.2857	acc=0.9028	5680.6 examples/second
# [Step=150]	Loss=0.2864	acc=0.9018	5528.0 examples/second
# Test Loss=0.3876, Test acc=0.8719
# Saving...
#
# Epoch: 10
# [Step=50]	Loss=0.2785	acc=0.9052	3704.5 examples/second
# [Step=100]	Loss=0.2823	acc=0.9037	5291.3 examples/second
# [Step=150]	Loss=0.2812	acc=0.9037	5779.5 examples/second
# Test Loss=0.3857, Test acc=0.8718
#
# Epoch: 11
# [Step=50]	Loss=0.2683	acc=0.9085	4133.5 examples/second
# [Step=100]	Loss=0.2741	acc=0.9057	5864.2 examples/second
# [Step=150]	Loss=0.2746	acc=0.9047	5524.7 examples/second
# Test Loss=0.3815, Test acc=0.8746
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2702	acc=0.9059	3856.5 examples/second
# [Step=100]	Loss=0.2670	acc=0.9088	5639.9 examples/second
# [Step=150]	Loss=0.2701	acc=0.9072	5834.2 examples/second
# Test Loss=0.3779, Test acc=0.8748
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2587	acc=0.9095	3688.8 examples/second
# [Step=100]	Loss=0.2650	acc=0.9079	5227.5 examples/second
# [Step=150]	Loss=0.2636	acc=0.9077	5864.0 examples/second
# Test Loss=0.3750, Test acc=0.8763
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2537	acc=0.9119	3584.2 examples/second
# [Step=100]	Loss=0.2568	acc=0.9113	5149.1 examples/second
# [Step=150]	Loss=0.2593	acc=0.9112	4848.7 examples/second
# Test Loss=0.3738, Test acc=0.8763
#
# Epoch: 15
# [Step=50]	Loss=0.2612	acc=0.9086	3964.8 examples/second
# [Step=100]	Loss=0.2562	acc=0.9108	5658.1 examples/second
# [Step=150]	Loss=0.2535	acc=0.9119	5706.6 examples/second
# Test Loss=0.3708, Test acc=0.8772
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2627	acc=0.9092	3950.4 examples/second
# [Step=100]	Loss=0.2627	acc=0.9087	5243.6 examples/second
# [Step=150]	Loss=0.2553	acc=0.9106	5320.3 examples/second
# Test Loss=0.3714, Test acc=0.8759
#
# Epoch: 17
# [Step=50]	Loss=0.2505	acc=0.9130	3745.7 examples/second
# [Step=100]	Loss=0.2522	acc=0.9132	5522.3 examples/second
# [Step=150]	Loss=0.2527	acc=0.9128	5500.9 examples/second
# Test Loss=0.3706, Test acc=0.8768
#
# Epoch: 18
# [Step=50]	Loss=0.2481	acc=0.9147	3781.0 examples/second
# [Step=100]	Loss=0.2434	acc=0.9168	4910.1 examples/second
# [Step=150]	Loss=0.2460	acc=0.9140	4975.8 examples/second
# Test Loss=0.3655, Test acc=0.8789
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2403	acc=0.9163	3933.6 examples/second
# [Step=100]	Loss=0.2376	acc=0.9176	5326.4 examples/second
# [Step=150]	Loss=0.2358	acc=0.9187	5288.3 examples/second
# Test Loss=0.3664, Test acc=0.8786

# %%
# Check sparsity of the finetuned model, make sure it's not changed
net.load_state_dict(torch.load("net_after_finetune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.data.cpu().numpy()
        # Count number of zeros
        zeros = np.sum(np_weight == 0)
        # Count number of parameters
        total = np.prod(np_weight.shape)
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3642, Test accuracy=0.8800

# %% [markdown]
# ### Lab2 (d) Iterative pruning

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    if epoch<10:
        for name,layer in net.named_modules():
            if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
                # Increase model sparsity
                # prune (8 × e)% before epoch e
                q = 8*(epoch+1)
                prune_by_percentage(layer, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0509	acc=0.9834	2795.6 examples/second
# [Step=100]	Loss=0.0479	acc=0.9843	5643.8 examples/second
# [Step=150]	Loss=0.0481	acc=0.9844	5255.0 examples/second
# Test Loss=0.3249, Test acc=0.9155
#
# Epoch: 1
# [Step=50]	Loss=0.0547	acc=0.9819	3549.5 examples/second
# [Step=100]	Loss=0.0524	acc=0.9831	4741.5 examples/second
# [Step=150]	Loss=0.0520	acc=0.9834	5614.4 examples/second
# Test Loss=0.3258, Test acc=0.9146
#
# Epoch: 2
# [Step=50]	Loss=0.0519	acc=0.9828	3527.0 examples/second
# [Step=100]	Loss=0.0533	acc=0.9822	5016.2 examples/second
# [Step=150]	Loss=0.0538	acc=0.9821	5491.6 examples/second
# Test Loss=0.3299, Test acc=0.9121
#
# Epoch: 3
# [Step=50]	Loss=0.0575	acc=0.9802	3295.4 examples/second
# [Step=100]	Loss=0.0570	acc=0.9809	5032.3 examples/second
# [Step=150]	Loss=0.0561	acc=0.9810	5089.4 examples/second
# Test Loss=0.3320, Test acc=0.9116
#
# Epoch: 4
# [Step=50]	Loss=0.0690	acc=0.9765	3659.1 examples/second
# [Step=100]	Loss=0.0706	acc=0.9757	4194.2 examples/second
# [Step=150]	Loss=0.0677	acc=0.9768	4900.9 examples/second
# Test Loss=0.3387, Test acc=0.9101
#
# Epoch: 5
# [Step=50]	Loss=0.0895	acc=0.9702	3579.6 examples/second
# [Step=100]	Loss=0.0867	acc=0.9712	4563.9 examples/second
# [Step=150]	Loss=0.0858	acc=0.9714	5124.5 examples/second
# Test Loss=0.3355, Test acc=0.9044
#
# Epoch: 6
# [Step=50]	Loss=0.1351	acc=0.9515	3488.6 examples/second
# [Step=100]	Loss=0.1270	acc=0.9553	5260.6 examples/second
# [Step=150]	Loss=0.1218	acc=0.9573	5565.5 examples/second
# Test Loss=0.3362, Test acc=0.9006
#
# Epoch: 7
# [Step=50]	Loss=0.1915	acc=0.9320	4007.4 examples/second
# [Step=100]	Loss=0.1781	acc=0.9362	5745.8 examples/second
# [Step=150]	Loss=0.1680	acc=0.9406	5414.9 examples/second
# Test Loss=0.3518, Test acc=0.8910
#
# Epoch: 8
# [Step=50]	Loss=0.2932	acc=0.8989	3570.3 examples/second
# [Step=100]	Loss=0.2634	acc=0.9093	4353.7 examples/second
# [Step=150]	Loss=0.2493	acc=0.9142	5121.8 examples/second
# Test Loss=0.3658, Test acc=0.8814
#
# Epoch: 9
# [Step=50]	Loss=0.5510	acc=0.8121	3340.0 examples/second
# [Step=100]	Loss=0.5088	acc=0.8256	4418.1 examples/second
# [Step=150]	Loss=0.4835	acc=0.8344	4707.4 examples/second
# Test Loss=0.4776, Test acc=0.8457
#
# Epoch: 10
# [Step=50]	Loss=0.3963	acc=0.8635	3505.7 examples/second
# [Step=100]	Loss=0.3768	acc=0.8704	4390.3 examples/second
# [Step=150]	Loss=0.3723	acc=0.8724	4155.9 examples/second
# Test Loss=0.4444, Test acc=0.8546
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.3426	acc=0.8802	4306.8 examples/second
# [Step=100]	Loss=0.3425	acc=0.8809	5433.0 examples/second
# [Step=150]	Loss=0.3418	acc=0.8805	5522.1 examples/second
# Test Loss=0.4270, Test acc=0.8595
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.3336	acc=0.8833	4521.9 examples/second
# [Step=100]	Loss=0.3285	acc=0.8851	4993.4 examples/second
# [Step=150]	Loss=0.3242	acc=0.8870	5316.2 examples/second
# Test Loss=0.4137, Test acc=0.8649
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.3146	acc=0.8895	3999.4 examples/second
# [Step=100]	Loss=0.3051	acc=0.8934	4585.0 examples/second
# [Step=150]	Loss=0.3071	acc=0.8927	4640.5 examples/second
# Test Loss=0.4052, Test acc=0.8646
#
# Epoch: 14
# [Step=50]	Loss=0.2966	acc=0.8984	3335.3 examples/second
# [Step=100]	Loss=0.2936	acc=0.8985	4492.3 examples/second
# [Step=150]	Loss=0.2925	acc=0.8992	4634.7 examples/second
# Test Loss=0.3980, Test acc=0.8691
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2857	acc=0.9022	3749.1 examples/second
# [Step=100]	Loss=0.2852	acc=0.9027	5180.5 examples/second
# [Step=150]	Loss=0.2847	acc=0.9021	5322.7 examples/second
# Test Loss=0.3936, Test acc=0.8694
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2840	acc=0.9025	4144.1 examples/second
# [Step=100]	Loss=0.2800	acc=0.9034	5247.6 examples/second
# [Step=150]	Loss=0.2782	acc=0.9039	5221.5 examples/second
# Test Loss=0.3895, Test acc=0.8714
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2809	acc=0.9012	3340.6 examples/second
# [Step=100]	Loss=0.2796	acc=0.9025	4881.3 examples/second
# [Step=150]	Loss=0.2729	acc=0.9049	5502.8 examples/second
# Test Loss=0.3837, Test acc=0.8736
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2587	acc=0.9101	4043.8 examples/second
# [Step=100]	Loss=0.2643	acc=0.9094	5263.7 examples/second
# [Step=150]	Loss=0.2642	acc=0.9094	5145.2 examples/second
# Test Loss=0.3801, Test acc=0.8743
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2639	acc=0.9083	3554.6 examples/second
# [Step=100]	Loss=0.2632	acc=0.9100	4712.8 examples/second
# [Step=150]	Loss=0.2642	acc=0.9103	4980.7 examples/second
# Test Loss=0.3763, Test acc=0.8761
# Saving...

# %%
# Check sparsity of the final model, make sure it's 80%
net.load_state_dict(torch.load("net_after_iterative_prune.pt"))

for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here: can copy from previous question
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.data.cpu().numpy()
        # Count number of zeros
        zeros = np.sum(np_weight == 0)
        # Count number of parameters
        total = np.prod(np_weight.shape)
        # Print sparsity
        print('Sparsity of '+name+': '+str(zeros/total))        
        
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.7986111111111112
# Sparsity of body_op.0.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.0.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.1.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.2.conv2.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv1.0.conv: 0.7999131944444444
# Sparsity of body_op.3.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.4.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv1.0.conv: 0.8000217013888888
# Sparsity of body_op.5.conv2.0.conv: 0.8000217013888888
# Sparsity of body_op.6.conv1.0.conv: 0.7999674479166666
# Sparsity of body_op.6.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.7.conv2.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv1.0.conv: 0.7999945746527778
# Sparsity of body_op.8.conv2.0.conv: 0.7999945746527778
# Sparsity of final_fc.linear: 0.8
# Files already downloaded and verified
# Test Loss=0.3763, Test accuracy=0.8761

# %% [markdown]
# ### Lab2 (e) Global iterative pruning

# %%
def global_prune_by_percentage(net, q=80.0):
    """
    Pruning the weight paramters by threshold.
    :param q: pruning percentile. 'q' percent of the least 
    significant weight parameters will be pruned.
    """
    # A list to gather all the weights
    flattened_weights = []
    # Find global pruning threshold
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = layer.weight.data.cpu().numpy()
            # Flatten the weight and append to flattened_weights
            flattened_weights.append(np_weight.flatten())
    # Concate all weights into a np array
    flattened_weights = np.concatenate(flattened_weights)
    # Find global pruning threshold
    thres = np.percentile(np.abs(flattened_weights), q)
    
    # Apply pruning threshold to all layers
    for name,layer in net.named_modules():
        if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
            # Convert weight to numpy
            np_weight = layer.weight.data.cpu().numpy()
            # Generate a binary mask same shape as weight to decide which element to prune
            mask = np.abs(np_weight) > thres
            # Convert mask to torch tensor and put on GPU
            mask = torch.from_numpy(mask).to(device)
            # Multiply the weight by mask to perform pruning
            layer.weight.data = layer.weight.data * mask

# %%
net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "net_after_global_iterative_prune.pt")
# Out:
# Epoch: 0
# [Step=50]	Loss=0.0492	acc=0.9838	3212.4 examples/second
# [Step=100]	Loss=0.0491	acc=0.9845	4469.8 examples/second
# [Step=150]	Loss=0.0489	acc=0.9847	4811.2 examples/second
# Test Loss=0.3256, Test acc=0.9141
#
# Epoch: 1
# [Step=50]	Loss=0.0512	acc=0.9840	3716.3 examples/second
# [Step=100]	Loss=0.0504	acc=0.9842	5080.0 examples/second
# [Step=150]	Loss=0.0507	acc=0.9839	4835.3 examples/second
# Test Loss=0.3250, Test acc=0.9159
#
# Epoch: 2
# [Step=50]	Loss=0.0477	acc=0.9851	3794.4 examples/second
# [Step=100]	Loss=0.0484	acc=0.9851	4769.4 examples/second
# [Step=150]	Loss=0.0491	acc=0.9850	5161.2 examples/second
# Test Loss=0.3268, Test acc=0.9147
#
# Epoch: 3
# [Step=50]	Loss=0.0523	acc=0.9831	3760.4 examples/second
# [Step=100]	Loss=0.0527	acc=0.9825	4539.5 examples/second
# [Step=150]	Loss=0.0534	acc=0.9821	4801.4 examples/second
# Test Loss=0.3277, Test acc=0.9134
#
# Epoch: 4
# [Step=50]	Loss=0.0570	acc=0.9816	4244.8 examples/second
# [Step=100]	Loss=0.0562	acc=0.9817	4502.7 examples/second
# [Step=150]	Loss=0.0573	acc=0.9814	4901.3 examples/second
# Test Loss=0.3238, Test acc=0.9120
#
# Epoch: 5
# [Step=50]	Loss=0.0762	acc=0.9745	4007.3 examples/second
# [Step=100]	Loss=0.0730	acc=0.9753	4687.6 examples/second
# [Step=150]	Loss=0.0712	acc=0.9761	4347.9 examples/second
# Test Loss=0.3271, Test acc=0.9077
#
# Epoch: 6
# [Step=50]	Loss=0.0949	acc=0.9670	3923.5 examples/second
# [Step=100]	Loss=0.0910	acc=0.9690	4910.6 examples/second
# [Step=150]	Loss=0.0895	acc=0.9700	4777.3 examples/second
# Test Loss=0.3270, Test acc=0.9066
#
# Epoch: 7
# [Step=50]	Loss=0.1365	acc=0.9541	3816.9 examples/second
# [Step=100]	Loss=0.1291	acc=0.9563	4426.1 examples/second
# [Step=150]	Loss=0.1260	acc=0.9569	5010.0 examples/second
# Test Loss=0.3259, Test acc=0.9026
#
# Epoch: 8
# [Step=50]	Loss=0.2069	acc=0.9296	3877.5 examples/second
# [Step=100]	Loss=0.1950	acc=0.9325	5087.2 examples/second
# [Step=150]	Loss=0.1884	acc=0.9348	4680.7 examples/second
# Test Loss=0.3395, Test acc=0.8876
#
# Epoch: 9
# [Step=50]	Loss=0.4149	acc=0.8594	3921.4 examples/second
# [Step=100]	Loss=0.3858	acc=0.8693	4791.0 examples/second
# [Step=150]	Loss=0.3717	acc=0.8743	4555.4 examples/second
# Test Loss=0.4221, Test acc=0.8554
#
# Epoch: 10
# [Step=50]	Loss=0.3267	acc=0.8893	4056.9 examples/second
# [Step=100]	Loss=0.3210	acc=0.8909	4823.2 examples/second
# [Step=150]	Loss=0.3122	acc=0.8949	5058.3 examples/second
# Test Loss=0.3967, Test acc=0.8641
# Saving...
#
# Epoch: 11
# [Step=50]	Loss=0.2833	acc=0.9043	3667.1 examples/second
# [Step=100]	Loss=0.2846	acc=0.9040	4853.2 examples/second
# [Step=150]	Loss=0.2875	acc=0.9028	4693.7 examples/second
# Test Loss=0.3837, Test acc=0.8699
# Saving...
#
# Epoch: 12
# [Step=50]	Loss=0.2697	acc=0.9095	3715.7 examples/second
# [Step=100]	Loss=0.2694	acc=0.9086	4975.3 examples/second
# [Step=150]	Loss=0.2730	acc=0.9079	4748.1 examples/second
# Test Loss=0.3757, Test acc=0.8742
# Saving...
#
# Epoch: 13
# [Step=50]	Loss=0.2675	acc=0.9102	3338.5 examples/second
# [Step=100]	Loss=0.2655	acc=0.9114	4819.6 examples/second
# [Step=150]	Loss=0.2636	acc=0.9118	4930.9 examples/second
# Test Loss=0.3685, Test acc=0.8747
# Saving...
#
# Epoch: 14
# [Step=50]	Loss=0.2614	acc=0.9098	3466.1 examples/second
# [Step=100]	Loss=0.2556	acc=0.9125	4546.2 examples/second
# [Step=150]	Loss=0.2550	acc=0.9128	5010.0 examples/second
# Test Loss=0.3630, Test acc=0.8772
# Saving...
#
# Epoch: 15
# [Step=50]	Loss=0.2560	acc=0.9115	3666.7 examples/second
# [Step=100]	Loss=0.2454	acc=0.9159	4727.2 examples/second
# [Step=150]	Loss=0.2458	acc=0.9163	4315.6 examples/second
# Test Loss=0.3584, Test acc=0.8783
# Saving...
#
# Epoch: 16
# [Step=50]	Loss=0.2380	acc=0.9187	3887.2 examples/second
# [Step=100]	Loss=0.2374	acc=0.9182	4681.8 examples/second
# [Step=150]	Loss=0.2362	acc=0.9190	4764.3 examples/second
# Test Loss=0.3563, Test acc=0.8804
# Saving...
#
# Epoch: 17
# [Step=50]	Loss=0.2397	acc=0.9160	3962.1 examples/second
# [Step=100]	Loss=0.2378	acc=0.9181	4576.8 examples/second
# [Step=150]	Loss=0.2337	acc=0.9203	5178.2 examples/second
# Test Loss=0.3515, Test acc=0.8820
# Saving...
#
# Epoch: 18
# [Step=50]	Loss=0.2403	acc=0.9183	4098.4 examples/second
# [Step=100]	Loss=0.2331	acc=0.9196	4274.2 examples/second
# [Step=150]	Loss=0.2296	acc=0.9214	4406.7 examples/second
# Test Loss=0.3493, Test acc=0.8821
# Saving...
#
# Epoch: 19
# [Step=50]	Loss=0.2194	acc=0.9271	3663.5 examples/second
# [Step=100]	Loss=0.2233	acc=0.9251	4696.2 examples/second
# [Step=150]	Loss=0.2236	acc=0.9248	4534.2 examples/second
# Test Loss=0.3469, Test acc=0.8834
# Saving...

# %%
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        # Your code here:
        # Convert the weight of "layer" to numpy array
        np_weight = layer.weight.data.cpu().numpy()
        # Count number of zeros
        zeros = np.sum(np_weight == 0)
        # Count number of parameters
        total = np.prod(np_weight.shape)
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
# Out:
# Sparsity of head_conv.0.conv: 0.3101851851851852
# Sparsity of body_op.0.conv1.0.conv: 0.6571180555555556
# Sparsity of body_op.0.conv2.0.conv: 0.6388888888888888
# Sparsity of body_op.1.conv1.0.conv: 0.6267361111111112
# Sparsity of body_op.1.conv2.0.conv: 0.6480034722222222
# Sparsity of body_op.2.conv1.0.conv: 0.6302083333333334
# Sparsity of body_op.2.conv2.0.conv: 0.6684027777777778
# Sparsity of body_op.3.conv1.0.conv: 0.6247829861111112
# Sparsity of body_op.3.conv2.0.conv: 0.6882595486111112
# Sparsity of body_op.4.conv1.0.conv: 0.7259114583333334
# Sparsity of body_op.4.conv2.0.conv: 0.7823350694444444
# Sparsity of body_op.5.conv1.0.conv: 0.7249348958333334
# Sparsity of body_op.5.conv2.0.conv: 0.8130425347222222
# Sparsity of body_op.6.conv1.0.conv: 0.7326388888888888
# Sparsity of body_op.6.conv2.0.conv: 0.764404296875
# Sparsity of body_op.7.conv1.0.conv: 0.7772081163194444
# Sparsity of body_op.7.conv2.0.conv: 0.8260633680555556
# Sparsity of body_op.8.conv1.0.conv: 0.8526746961805556
# Sparsity of body_op.8.conv2.0.conv: 0.9766981336805556
# Sparsity of final_fc.linear: 0.15625
# Total sparsity of: 0.8000007453342078
# Files already downloaded and verified
# Test Loss=0.3469, Test accuracy=0.8834

# %% [markdown]
# ### Lab 3 (b) and (c): Fixed-point quantization

# %%
# Define quantized model and load weight
Nbits = None #Change this value to finish (b) and (c)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3231, Test accuracy=0.9151

# %%
nbits_lst = [6, 5, 4, 3, 2]

for nbit in nbits_lst:
    Nbits = nbit
    net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
    net = net.to(device)
    net.load_state_dict(torch.load("pretrained_model.pt"))
    test(net)
# Out:
# Files already downloaded and verified
# Test Loss=0.3364, Test accuracy=0.9145
# Files already downloaded and verified
# Test Loss=0.3390, Test accuracy=0.9112
# Files already downloaded and verified
# Test Loss=0.3861, Test accuracy=0.8972
# Files already downloaded and verified
# Test Loss=0.9874, Test accuracy=0.7662
# Files already downloaded and verified
# Test Loss=9.5441, Test accuracy=0.0899

# %%
nbit_lst = [4, 3, 2]

for nbit in nbit_lst:
    print("Nbits:", nbit)
    net = ResNetCIFAR(num_layers=20, Nbits=nbit)
    net = net.to(device)
    net.load_state_dict(torch.load("pretrained_model.pt"))
    # Quantized model finetuning
    finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)   

    # Load the model with best accuracy
    net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
    test(net)
# Out:
# Nbits: 4
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.0702	acc=0.9745	2546.7 examples/second
# [Step=100]	Loss=0.0658	acc=0.9770	3819.3 examples/second
# [Step=150]	Loss=0.0663	acc=0.9771	4591.5 examples/second
# Test Loss=0.3344, Test acc=0.9071
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.0464	acc=0.9834	1775.8 examples/second
# [Step=250]	Loss=0.0664	acc=0.9777	4936.4 examples/second
# [Step=300]	Loss=0.0643	acc=0.9781	5021.0 examples/second
# [Step=350]	Loss=0.0637	acc=0.9786	5016.0 examples/second
# Test Loss=0.3363, Test acc=0.9105
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.0461	acc=0.9878	1731.2 examples/second
# [Step=450]	Loss=0.0594	acc=0.9802	4163.2 examples/second
# [Step=500]	Loss=0.0614	acc=0.9789	4161.8 examples/second
# [Step=550]	Loss=0.0616	acc=0.9788	4364.8 examples/second
# Test Loss=0.3328, Test acc=0.9093
#
# Epoch: 3
# [Step=600]	Loss=0.0543	acc=0.9814	1972.9 examples/second
# [Step=650]	Loss=0.0539	acc=0.9820	4482.4 examples/second
# [Step=700]	Loss=0.0564	acc=0.9815	4402.3 examples/second
# [Step=750]	Loss=0.0585	acc=0.9804	4359.6 examples/second
# Test Loss=0.3370, Test acc=0.9092
#
# Epoch: 4
# [Step=800]	Loss=0.0605	acc=0.9795	2032.4 examples/second
# [Step=850]	Loss=0.0624	acc=0.9780	3949.4 examples/second
# [Step=900]	Loss=0.0618	acc=0.9785	4564.6 examples/second
# [Step=950]	Loss=0.0593	acc=0.9795	4580.4 examples/second
# Test Loss=0.3291, Test acc=0.9132
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.0556	acc=0.9793	1753.1 examples/second
# [Step=1050]	Loss=0.0566	acc=0.9807	3860.0 examples/second
# [Step=1100]	Loss=0.0577	acc=0.9808	4604.0 examples/second
# [Step=1150]	Loss=0.0558	acc=0.9816	4151.6 examples/second
# Test Loss=0.3316, Test acc=0.9114
#
# Epoch: 6
# [Step=1200]	Loss=0.0623	acc=0.9785	1976.9 examples/second
# [Step=1250]	Loss=0.0586	acc=0.9797	3795.1 examples/second
# [Step=1300]	Loss=0.0589	acc=0.9795	4353.8 examples/second
# [Step=1350]	Loss=0.0574	acc=0.9804	4544.4 examples/second
# Test Loss=0.3332, Test acc=0.9098
#
# Epoch: 7
# [Step=1400]	Loss=0.0572	acc=0.9803	1913.3 examples/second
# [Step=1450]	Loss=0.0561	acc=0.9817	3842.8 examples/second
# [Step=1500]	Loss=0.0562	acc=0.9815	4538.1 examples/second
# [Step=1550]	Loss=0.0567	acc=0.9815	4472.4 examples/second
# Test Loss=0.3356, Test acc=0.9124
#
# Epoch: 8
# [Step=1600]	Loss=0.0562	acc=0.9811	1964.3 examples/second
# [Step=1650]	Loss=0.0559	acc=0.9809	4722.6 examples/second
# [Step=1700]	Loss=0.0553	acc=0.9810	4631.1 examples/second
# [Step=1750]	Loss=0.0554	acc=0.9813	4361.0 examples/second
# Test Loss=0.3330, Test acc=0.9128
#
# Epoch: 9
# [Step=1800]	Loss=0.0544	acc=0.9822	1895.6 examples/second
# [Step=1850]	Loss=0.0584	acc=0.9804	4229.6 examples/second
# [Step=1900]	Loss=0.0586	acc=0.9802	4342.9 examples/second
# [Step=1950]	Loss=0.0578	acc=0.9807	4372.5 examples/second
# Test Loss=0.3349, Test acc=0.9123
#
# Epoch: 10
# [Step=2000]	Loss=0.0522	acc=0.9822	1902.6 examples/second
# [Step=2050]	Loss=0.0528	acc=0.9826	4540.9 examples/second
# [Step=2100]	Loss=0.0527	acc=0.9827	4326.9 examples/second
# [Step=2150]	Loss=0.0540	acc=0.9823	4680.7 examples/second
# Test Loss=0.3340, Test acc=0.9121
#
# Epoch: 11
# [Step=2200]	Loss=0.0517	acc=0.9825	2011.0 examples/second
# [Step=2250]	Loss=0.0547	acc=0.9817	4865.9 examples/second
# [Step=2300]	Loss=0.0558	acc=0.9813	4618.1 examples/second
# [Step=2350]	Loss=0.0557	acc=0.9815	4139.9 examples/second
# Test Loss=0.3339, Test acc=0.9124
#
# Epoch: 12
# [Step=2400]	Loss=0.0553	acc=0.9814	1912.9 examples/second
# [Step=2450]	Loss=0.0553	acc=0.9820	4174.1 examples/second
# [Step=2500]	Loss=0.0550	acc=0.9818	4794.8 examples/second
# Test Loss=0.3389, Test acc=0.9103
#
# Epoch: 13
# [Step=2550]	Loss=0.0367	acc=0.9941	2017.9 examples/second
# [Step=2600]	Loss=0.0550	acc=0.9805	4413.5 examples/second
# [Step=2650]	Loss=0.0560	acc=0.9805	4213.1 examples/second
# [Step=2700]	Loss=0.0545	acc=0.9813	4338.8 examples/second
# Test Loss=0.3337, Test acc=0.9123
#
# Epoch: 14
# [Step=2750]	Loss=0.0495	acc=0.9837	1901.1 examples/second
# [Step=2800]	Loss=0.0571	acc=0.9796	4012.2 examples/second
# [Step=2850]	Loss=0.0549	acc=0.9818	4163.0 examples/second
# [Step=2900]	Loss=0.0545	acc=0.9816	4570.6 examples/second
# Test Loss=0.3331, Test acc=0.9111
#
# Epoch: 15
# [Step=2950]	Loss=0.0575	acc=0.9812	1895.7 examples/second
# [Step=3000]	Loss=0.0553	acc=0.9820	4494.9 examples/second
# [Step=3050]	Loss=0.0542	acc=0.9822	4092.6 examples/second
# [Step=3100]	Loss=0.0533	acc=0.9826	4324.3 examples/second
# Test Loss=0.3350, Test acc=0.9121
#
# Epoch: 16
# [Step=3150]	Loss=0.0538	acc=0.9833	1877.6 examples/second
# [Step=3200]	Loss=0.0550	acc=0.9828	4570.5 examples/second
# [Step=3250]	Loss=0.0526	acc=0.9836	4654.7 examples/second
# [Step=3300]	Loss=0.0527	acc=0.9833	4644.0 examples/second
# Test Loss=0.3417, Test acc=0.9096
#
# Epoch: 17
# [Step=3350]	Loss=0.0475	acc=0.9852	1979.4 examples/second
# [Step=3400]	Loss=0.0501	acc=0.9832	4371.9 examples/second
# [Step=3450]	Loss=0.0515	acc=0.9824	4249.2 examples/second
# [Step=3500]	Loss=0.0520	acc=0.9825	4351.0 examples/second
# Test Loss=0.3338, Test acc=0.9106
#
# Epoch: 18
# [Step=3550]	Loss=0.0528	acc=0.9833	1955.9 examples/second
# [Step=3600]	Loss=0.0520	acc=0.9828	4389.4 examples/second
# [Step=3650]	Loss=0.0519	acc=0.9830	4731.5 examples/second
# [Step=3700]	Loss=0.0523	acc=0.9826	4239.4 examples/second
# Test Loss=0.3324, Test acc=0.9121
#
# Epoch: 19
# [Step=3750]	Loss=0.0521	acc=0.9823	1937.3 examples/second
# [Step=3800]	Loss=0.0552	acc=0.9809	4531.6 examples/second
# [Step=3850]	Loss=0.0551	acc=0.9811	4435.1 examples/second
# [Step=3900]	Loss=0.0547	acc=0.9813	4513.3 examples/second
# Test Loss=0.3350, Test acc=0.9112
# Files already downloaded and verified
# Test Loss=0.3291, Test accuracy=0.9132
# Nbits: 3
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=0.1736	acc=0.9394	3393.7 examples/second
# [Step=100]	Loss=0.1585	acc=0.9434	4461.2 examples/second
# [Step=150]	Loss=0.1537	acc=0.9448	4631.3 examples/second
# Test Loss=0.3943, Test acc=0.8944
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.1246	acc=0.9580	1735.0 examples/second
# [Step=250]	Loss=0.1279	acc=0.9552	4628.1 examples/second
# [Step=300]	Loss=0.1257	acc=0.9556	4476.1 examples/second
# [Step=350]	Loss=0.1210	acc=0.9569	4367.8 examples/second
# Test Loss=0.3816, Test acc=0.8992
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.1280	acc=0.9531	1804.7 examples/second
# [Step=450]	Loss=0.1129	acc=0.9582	4062.6 examples/second
# [Step=500]	Loss=0.1116	acc=0.9590	4625.2 examples/second
# [Step=550]	Loss=0.1118	acc=0.9594	4157.8 examples/second
# Test Loss=0.3817, Test acc=0.8991
#
# Epoch: 3
# [Step=600]	Loss=0.1011	acc=0.9606	1897.6 examples/second
# [Step=650]	Loss=0.1100	acc=0.9598	4267.7 examples/second
# [Step=700]	Loss=0.1086	acc=0.9605	4454.2 examples/second
# [Step=750]	Loss=0.1087	acc=0.9608	3970.5 examples/second
# Test Loss=0.3753, Test acc=0.8991
#
# Epoch: 4
# [Step=800]	Loss=0.0974	acc=0.9661	1973.9 examples/second
# [Step=850]	Loss=0.1013	acc=0.9641	4431.5 examples/second
# [Step=900]	Loss=0.1056	acc=0.9625	4221.2 examples/second
# [Step=950]	Loss=0.1046	acc=0.9628	4152.7 examples/second
# Test Loss=0.3688, Test acc=0.9048
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.0958	acc=0.9641	1702.7 examples/second
# [Step=1050]	Loss=0.0985	acc=0.9625	4439.3 examples/second
# [Step=1100]	Loss=0.1013	acc=0.9630	4525.0 examples/second
# [Step=1150]	Loss=0.1000	acc=0.9634	4589.8 examples/second
# Test Loss=0.3647, Test acc=0.9029
#
# Epoch: 6
# [Step=1200]	Loss=0.1021	acc=0.9639	1971.5 examples/second
# [Step=1250]	Loss=0.0993	acc=0.9649	4501.0 examples/second
# [Step=1300]	Loss=0.0995	acc=0.9643	4549.8 examples/second
# [Step=1350]	Loss=0.1003	acc=0.9638	4118.2 examples/second
# Test Loss=0.3670, Test acc=0.9033
#
# Epoch: 7
# [Step=1400]	Loss=0.0883	acc=0.9676	1881.9 examples/second
# [Step=1450]	Loss=0.0921	acc=0.9663	4299.4 examples/second
# [Step=1500]	Loss=0.0926	acc=0.9659	3950.0 examples/second
# [Step=1550]	Loss=0.0948	acc=0.9655	4188.8 examples/second
# Test Loss=0.3660, Test acc=0.9038
#
# Epoch: 8
# [Step=1600]	Loss=0.0872	acc=0.9691	1928.9 examples/second
# [Step=1650]	Loss=0.0939	acc=0.9663	4166.8 examples/second
# [Step=1700]	Loss=0.0930	acc=0.9663	4168.2 examples/second
# [Step=1750]	Loss=0.0949	acc=0.9658	4077.4 examples/second
# Test Loss=0.3613, Test acc=0.9034
#
# Epoch: 9
# [Step=1800]	Loss=0.0924	acc=0.9667	1940.4 examples/second
# [Step=1850]	Loss=0.0934	acc=0.9656	4029.7 examples/second
# [Step=1900]	Loss=0.0951	acc=0.9653	4430.4 examples/second
# [Step=1950]	Loss=0.0950	acc=0.9655	4199.3 examples/second
# Test Loss=0.3601, Test acc=0.9033
#
# Epoch: 10
# [Step=2000]	Loss=0.0928	acc=0.9666	1953.4 examples/second
# [Step=2050]	Loss=0.0925	acc=0.9666	4442.4 examples/second
# [Step=2100]	Loss=0.0934	acc=0.9660	4833.6 examples/second
# [Step=2150]	Loss=0.0938	acc=0.9661	4291.0 examples/second
# Test Loss=0.3593, Test acc=0.9044
#
# Epoch: 11
# [Step=2200]	Loss=0.0926	acc=0.9666	1885.6 examples/second
# [Step=2250]	Loss=0.0929	acc=0.9669	4520.5 examples/second
# [Step=2300]	Loss=0.0918	acc=0.9678	4470.4 examples/second
# [Step=2350]	Loss=0.0913	acc=0.9678	4393.5 examples/second
# Test Loss=0.3630, Test acc=0.9043
#
# Epoch: 12
# [Step=2400]	Loss=0.0870	acc=0.9682	1922.8 examples/second
# [Step=2450]	Loss=0.0873	acc=0.9689	4230.3 examples/second
# [Step=2500]	Loss=0.0886	acc=0.9685	4473.3 examples/second
# Test Loss=0.3618, Test acc=0.9033
#
# Epoch: 13
# [Step=2550]	Loss=0.0797	acc=0.9727	1827.1 examples/second
# [Step=2600]	Loss=0.0846	acc=0.9685	4652.6 examples/second
# [Step=2650]	Loss=0.0875	acc=0.9679	4214.6 examples/second
# [Step=2700]	Loss=0.0875	acc=0.9684	4319.9 examples/second
# Test Loss=0.3567, Test acc=0.9037
#
# Epoch: 14
# [Step=2750]	Loss=0.0789	acc=0.9727	1927.3 examples/second
# [Step=2800]	Loss=0.0894	acc=0.9678	4211.6 examples/second
# [Step=2850]	Loss=0.0868	acc=0.9687	4138.6 examples/second
# [Step=2900]	Loss=0.0873	acc=0.9689	4506.0 examples/second
# Test Loss=0.3572, Test acc=0.9028
#
# Epoch: 15
# [Step=2950]	Loss=0.1007	acc=0.9652	1912.3 examples/second
# [Step=3000]	Loss=0.0880	acc=0.9704	4070.3 examples/second
# [Step=3050]	Loss=0.0880	acc=0.9700	4393.3 examples/second
# [Step=3100]	Loss=0.0893	acc=0.9689	4393.5 examples/second
# Test Loss=0.3687, Test acc=0.9036
#
# Epoch: 16
# [Step=3150]	Loss=0.0770	acc=0.9746	1938.9 examples/second
# [Step=3200]	Loss=0.0858	acc=0.9716	4473.6 examples/second
# [Step=3250]	Loss=0.0872	acc=0.9704	4480.6 examples/second
# [Step=3300]	Loss=0.0878	acc=0.9697	4273.3 examples/second
# Test Loss=0.3657, Test acc=0.9044
#
# Epoch: 17
# [Step=3350]	Loss=0.0884	acc=0.9664	1937.3 examples/second
# [Step=3400]	Loss=0.0864	acc=0.9685	4030.6 examples/second
# [Step=3450]	Loss=0.0856	acc=0.9689	4404.0 examples/second
# [Step=3500]	Loss=0.0849	acc=0.9693	4271.4 examples/second
# Test Loss=0.3558, Test acc=0.9042
#
# Epoch: 18
# [Step=3550]	Loss=0.0845	acc=0.9716	1897.6 examples/second
# [Step=3600]	Loss=0.0849	acc=0.9704	4191.7 examples/second
# [Step=3650]	Loss=0.0840	acc=0.9708	4191.4 examples/second
# [Step=3700]	Loss=0.0858	acc=0.9695	4239.7 examples/second
# Test Loss=0.3682, Test acc=0.9029
#
# Epoch: 19
# [Step=3750]	Loss=0.0783	acc=0.9721	1853.8 examples/second
# [Step=3800]	Loss=0.0847	acc=0.9703	4345.9 examples/second
# [Step=3850]	Loss=0.0844	acc=0.9705	4572.5 examples/second
# [Step=3900]	Loss=0.0843	acc=0.9703	4082.3 examples/second
# Test Loss=0.3579, Test acc=0.9049
# Saving...
# Files already downloaded and verified
# Test Loss=0.3579, Test accuracy=0.9049
# Nbits: 2
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=1.3515	acc=0.6227	3201.1 examples/second
# [Step=100]	Loss=1.0714	acc=0.6821	4327.8 examples/second
# [Step=150]	Loss=0.9484	acc=0.7122	4665.3 examples/second
# Test Loss=0.7392, Test acc=0.7757
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.6180	acc=0.8018	1729.7 examples/second
# [Step=250]	Loss=0.5702	acc=0.8097	4428.4 examples/second
# [Step=300]	Loss=0.5534	acc=0.8134	4405.3 examples/second
# [Step=350]	Loss=0.5429	acc=0.8172	4256.5 examples/second
# Test Loss=0.6307, Test acc=0.8066
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.4695	acc=0.8481	1716.3 examples/second
# [Step=450]	Loss=0.4758	acc=0.8431	4458.9 examples/second
# [Step=500]	Loss=0.4718	acc=0.8405	4354.9 examples/second
# [Step=550]	Loss=0.4626	acc=0.8426	4463.8 examples/second
# Test Loss=0.6330, Test acc=0.8110
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.4072	acc=0.8597	1685.8 examples/second
# [Step=650]	Loss=0.4338	acc=0.8531	4295.4 examples/second
# [Step=700]	Loss=0.4307	acc=0.8523	4291.9 examples/second

# %%
print("Nbits:", 2)
net = ResNetCIFAR(num_layers=20, Nbits=2)
net = net.to(device)
net.load_state_dict(torch.load("pretrained_model.pt"))
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)   

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# Nbits: 2
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=1.3528	acc=0.6161	2556.7 examples/second
# [Step=100]	Loss=1.0749	acc=0.6821	4770.0 examples/second
# [Step=150]	Loss=0.9471	acc=0.7139	4799.2 examples/second
# Test Loss=0.7775, Test acc=0.7664
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.5379	acc=0.8076	1669.8 examples/second
# [Step=250]	Loss=0.5697	acc=0.8090	4771.2 examples/second
# [Step=300]	Loss=0.5573	acc=0.8119	4488.7 examples/second
# [Step=350]	Loss=0.5434	acc=0.8162	4716.9 examples/second
# Test Loss=0.6802, Test acc=0.7972
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.4659	acc=0.8442	1814.0 examples/second
# [Step=450]	Loss=0.4764	acc=0.8353	4435.6 examples/second
# [Step=500]	Loss=0.4680	acc=0.8383	4592.0 examples/second
# [Step=550]	Loss=0.4647	acc=0.8396	4742.3 examples/second
# Test Loss=0.6145, Test acc=0.8114
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.4342	acc=0.8532	1774.1 examples/second
# [Step=650]	Loss=0.4387	acc=0.8474	4420.6 examples/second
# [Step=700]	Loss=0.4345	acc=0.8479	3676.0 examples/second
# [Step=750]	Loss=0.4294	acc=0.8499	3812.1 examples/second
# Test Loss=0.5557, Test acc=0.8268
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.4269	acc=0.8511	1392.5 examples/second
# [Step=850]	Loss=0.4138	acc=0.8562	3359.8 examples/second
# [Step=900]	Loss=0.4059	acc=0.8588	3421.0 examples/second
# [Step=950]	Loss=0.4003	acc=0.8613	3488.1 examples/second
# Test Loss=0.5443, Test acc=0.8352
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.3830	acc=0.8615	1418.2 examples/second
# [Step=1050]	Loss=0.3789	acc=0.8657	4380.7 examples/second
# [Step=1100]	Loss=0.3761	acc=0.8685	4558.6 examples/second
# [Step=1150]	Loss=0.3754	acc=0.8688	4444.7 examples/second
# Test Loss=0.5843, Test acc=0.8195
#
# Epoch: 6
# [Step=1200]	Loss=0.3592	acc=0.8757	1879.0 examples/second
# [Step=1250]	Loss=0.3636	acc=0.8729	3832.6 examples/second
# [Step=1300]	Loss=0.3594	acc=0.8733	4618.3 examples/second
# [Step=1350]	Loss=0.3609	acc=0.8720	4383.0 examples/second
# Test Loss=0.4796, Test acc=0.8484
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.3656	acc=0.8714	1645.7 examples/second
# [Step=1450]	Loss=0.3575	acc=0.8746	4693.3 examples/second
# [Step=1500]	Loss=0.3533	acc=0.8752	4710.0 examples/second
# [Step=1550]	Loss=0.3528	acc=0.8760	4432.0 examples/second
# Test Loss=0.5183, Test acc=0.8430
#
# Epoch: 8
# [Step=1600]	Loss=0.3278	acc=0.8870	1912.2 examples/second
# [Step=1650]	Loss=0.3308	acc=0.8841	4603.8 examples/second
# [Step=1700]	Loss=0.3312	acc=0.8827	4666.1 examples/second
# [Step=1750]	Loss=0.3366	acc=0.8817	4861.0 examples/second
# Test Loss=0.4985, Test acc=0.8469
#
# Epoch: 9
# [Step=1800]	Loss=0.3076	acc=0.8936	2078.6 examples/second
# [Step=1850]	Loss=0.3259	acc=0.8861	4380.0 examples/second
# [Step=1900]	Loss=0.3243	acc=0.8871	4776.2 examples/second
# [Step=1950]	Loss=0.3249	acc=0.8866	4410.9 examples/second
# Test Loss=0.5302, Test acc=0.8384
#
# Epoch: 10
# [Step=2000]	Loss=0.3249	acc=0.8877	2029.2 examples/second
# [Step=2050]	Loss=0.3316	acc=0.8840	4754.0 examples/second
# [Step=2100]	Loss=0.3314	acc=0.8835	4795.5 examples/second
# [Step=2150]	Loss=0.3267	acc=0.8846	4771.1 examples/second
# Test Loss=0.5722, Test acc=0.8296
#
# Epoch: 11
# [Step=2200]	Loss=0.3168	acc=0.8865	1892.1 examples/second
# [Step=2250]	Loss=0.3164	acc=0.8879	4445.0 examples/second
# [Step=2300]	Loss=0.3173	acc=0.8870	4361.3 examples/second
# [Step=2350]	Loss=0.3161	acc=0.8878	4381.8 examples/second
# Test Loss=0.4895, Test acc=0.8442
#
# Epoch: 12
# [Step=2400]	Loss=0.3059	acc=0.8909	1952.4 examples/second
# [Step=2450]	Loss=0.3139	acc=0.8890	4291.2 examples/second
# [Step=2500]	Loss=0.3136	acc=0.8888	4278.4 examples/second
# Test Loss=0.4767, Test acc=0.8488
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=0.3138	acc=0.8848	1794.7 examples/second
# [Step=2600]	Loss=0.3092	acc=0.8920	4076.2 examples/second
# [Step=2650]	Loss=0.3087	acc=0.8925	4528.1 examples/second
# [Step=2700]	Loss=0.3106	acc=0.8920	4540.7 examples/second
# Test Loss=0.5110, Test acc=0.8422
#
# Epoch: 14
# [Step=2750]	Loss=0.3016	acc=0.8913	2075.8 examples/second
# [Step=2800]	Loss=0.3086	acc=0.8891	4431.6 examples/second
# [Step=2850]	Loss=0.3029	acc=0.8927	4275.5 examples/second
# [Step=2900]	Loss=0.2997	acc=0.8942	4661.3 examples/second
# Test Loss=0.4726, Test acc=0.8544
# Saving...
#
# Epoch: 15
# [Step=2950]	Loss=0.3008	acc=0.8957	1888.7 examples/second
# [Step=3000]	Loss=0.2967	acc=0.8943	4413.7 examples/second
# [Step=3050]	Loss=0.3031	acc=0.8928	4506.7 examples/second
# [Step=3100]	Loss=0.3011	acc=0.8937	4429.4 examples/second
# Test Loss=0.4797, Test acc=0.8530
#
# Epoch: 16
# [Step=3150]	Loss=0.2949	acc=0.8956	2017.3 examples/second
# [Step=3200]	Loss=0.2944	acc=0.8958	4358.7 examples/second
# [Step=3250]	Loss=0.2922	acc=0.8956	4706.3 examples/second
# [Step=3300]	Loss=0.2931	acc=0.8958	4312.8 examples/second
# Test Loss=0.5119, Test acc=0.8473
#
# Epoch: 17
# [Step=3350]	Loss=0.2891	acc=0.8954	1987.6 examples/second
# [Step=3400]	Loss=0.2874	acc=0.8994	4185.9 examples/second
# [Step=3450]	Loss=0.2857	acc=0.8996	4678.7 examples/second
# [Step=3500]	Loss=0.2833	acc=0.8997	4744.2 examples/second
# Test Loss=0.4408, Test acc=0.8590
# Saving...
#
# Epoch: 18
# [Step=3550]	Loss=0.2928	acc=0.8995	1649.5 examples/second
# [Step=3600]	Loss=0.2821	acc=0.9026	4523.6 examples/second
# [Step=3650]	Loss=0.2798	acc=0.9025	4604.8 examples/second
# [Step=3700]	Loss=0.2820	acc=0.9015	4196.8 examples/second
# Test Loss=0.5631, Test acc=0.8333
#
# Epoch: 19
# [Step=3750]	Loss=0.2855	acc=0.9001	1934.0 examples/second
# [Step=3800]	Loss=0.2752	acc=0.9038	3964.0 examples/second
# [Step=3850]	Loss=0.2788	acc=0.9018	4630.7 examples/second
# [Step=3900]	Loss=0.2759	acc=0.9026	4451.1 examples/second
# Test Loss=0.4684, Test acc=0.8510
# Files already downloaded and verified
# Test Loss=0.4408, Test accuracy=0.8590

# %% [markdown]
# ### Lab3 (d) Quantize pruned model

# %%
Nbits = 4 
net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)

# %%
# Define quantized model and load weight
Nbits = 3 #Change this value to finish (d)

net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
# Out:
# Files already downloaded and verified
# Test Loss=4.2843, Test accuracy=0.0924

# %%
# Quantized model finetuning
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
#
# Epoch: 0
# [Step=50]	Loss=2.1449	acc=0.3780	3386.1 examples/second
# [Step=100]	Loss=1.7209	acc=0.4602	4246.5 examples/second
# [Step=150]	Loss=1.5050	acc=0.5140	4636.2 examples/second
# Test Loss=0.8544, Test acc=0.7007
# Saving...
#
# Epoch: 1
# [Step=200]	Loss=0.8195	acc=0.6914	1666.9 examples/second
# [Step=250]	Loss=0.8017	acc=0.7169	4636.7 examples/second
# [Step=300]	Loss=0.7591	acc=0.7332	3975.3 examples/second
# [Step=350]	Loss=0.7270	acc=0.7440	4027.8 examples/second
# Test Loss=0.6286, Test acc=0.7846
# Saving...
#
# Epoch: 2
# [Step=400]	Loss=0.6057	acc=0.7905	1492.9 examples/second
# [Step=450]	Loss=0.5814	acc=0.8015	4015.6 examples/second
# [Step=500]	Loss=0.5707	acc=0.8045	3862.4 examples/second
# [Step=550]	Loss=0.5620	acc=0.8079	4341.6 examples/second
# Test Loss=0.5724, Test acc=0.8055
# Saving...
#
# Epoch: 3
# [Step=600]	Loss=0.5153	acc=0.8301	1607.5 examples/second
# [Step=650]	Loss=0.5012	acc=0.8325	4037.1 examples/second
# [Step=700]	Loss=0.5018	acc=0.8295	3625.8 examples/second
# [Step=750]	Loss=0.4972	acc=0.8301	3725.4 examples/second
# Test Loss=0.5364, Test acc=0.8190
# Saving...
#
# Epoch: 4
# [Step=800]	Loss=0.4599	acc=0.8428	1679.5 examples/second
# [Step=850]	Loss=0.4539	acc=0.8436	4183.5 examples/second
# [Step=900]	Loss=0.4491	acc=0.8438	4249.5 examples/second
# [Step=950]	Loss=0.4459	acc=0.8451	4191.8 examples/second
# Test Loss=0.5120, Test acc=0.8272
# Saving...
#
# Epoch: 5
# [Step=1000]	Loss=0.4247	acc=0.8551	1637.6 examples/second
# [Step=1050]	Loss=0.4204	acc=0.8540	4622.5 examples/second
# [Step=1100]	Loss=0.4162	acc=0.8558	4416.6 examples/second
# [Step=1150]	Loss=0.4106	acc=0.8574	4330.3 examples/second
# Test Loss=0.4934, Test acc=0.8315
# Saving...
#
# Epoch: 6
# [Step=1200]	Loss=0.3848	acc=0.8651	1632.5 examples/second
# [Step=1250]	Loss=0.3894	acc=0.8649	4257.0 examples/second
# [Step=1300]	Loss=0.3875	acc=0.8667	3954.1 examples/second
# [Step=1350]	Loss=0.3861	acc=0.8659	3910.0 examples/second
# Test Loss=0.4625, Test acc=0.8444
# Saving...
#
# Epoch: 7
# [Step=1400]	Loss=0.3701	acc=0.8723	1583.0 examples/second
# [Step=1450]	Loss=0.3672	acc=0.8738	4124.0 examples/second
# [Step=1500]	Loss=0.3693	acc=0.8723	4353.9 examples/second
# [Step=1550]	Loss=0.3676	acc=0.8727	4235.9 examples/second
# Test Loss=0.4562, Test acc=0.8471
# Saving...
#
# Epoch: 8
# [Step=1600]	Loss=0.3548	acc=0.8766	1619.0 examples/second
# [Step=1650]	Loss=0.3529	acc=0.8772	4153.6 examples/second
# [Step=1700]	Loss=0.3500	acc=0.8795	3951.1 examples/second
# [Step=1750]	Loss=0.3524	acc=0.8786	3816.8 examples/second
# Test Loss=0.4466, Test acc=0.8528
# Saving...
#
# Epoch: 9
# [Step=1800]	Loss=0.3468	acc=0.8802	1679.2 examples/second
# [Step=1850]	Loss=0.3379	acc=0.8822	4206.7 examples/second
# [Step=1900]	Loss=0.3341	acc=0.8834	3926.3 examples/second
# [Step=1950]	Loss=0.3348	acc=0.8825	3767.2 examples/second
# Test Loss=0.4291, Test acc=0.8583
# Saving...
#
# Epoch: 10
# [Step=2000]	Loss=0.3326	acc=0.8844	1629.8 examples/second
# [Step=2050]	Loss=0.3266	acc=0.8860	3836.9 examples/second
# [Step=2100]	Loss=0.3276	acc=0.8854	4329.3 examples/second
# [Step=2150]	Loss=0.3271	acc=0.8856	3940.0 examples/second
# Test Loss=0.4269, Test acc=0.8557
#
# Epoch: 11
# [Step=2200]	Loss=0.3169	acc=0.8924	1982.0 examples/second
# [Step=2250]	Loss=0.3175	acc=0.8908	4319.0 examples/second
# [Step=2300]	Loss=0.3162	acc=0.8902	4151.5 examples/second
# [Step=2350]	Loss=0.3145	acc=0.8904	3921.3 examples/second
# Test Loss=0.4272, Test acc=0.8581
#
# Epoch: 12
# [Step=2400]	Loss=0.3054	acc=0.8933	1804.5 examples/second
# [Step=2450]	Loss=0.3053	acc=0.8942	3960.7 examples/second
# [Step=2500]	Loss=0.3087	acc=0.8919	4374.3 examples/second
# Test Loss=0.4110, Test acc=0.8622
# Saving...
#
# Epoch: 13
# [Step=2550]	Loss=0.3760	acc=0.8633	1574.7 examples/second
# [Step=2600]	Loss=0.2957	acc=0.8927	4231.2 examples/second
# [Step=2650]	Loss=0.2971	acc=0.8944	3727.4 examples/second
# [Step=2700]	Loss=0.2971	acc=0.8944	4270.0 examples/second
# Test Loss=0.4123, Test acc=0.8656
# Saving...
#
# Epoch: 14
# [Step=2750]	Loss=0.2911	acc=0.9036	1627.2 examples/second
# [Step=2800]	Loss=0.3015	acc=0.8951	4506.9 examples/second
# [Step=2850]	Loss=0.2942	acc=0.8971	4397.3 examples/second
# [Step=2900]	Loss=0.2931	acc=0.8974	4368.6 examples/second
# Test Loss=0.4029, Test acc=0.8627
#
# Epoch: 15
# [Step=2950]	Loss=0.3140	acc=0.8949	1838.1 examples/second
# [Step=3000]	Loss=0.2915	acc=0.8980	4423.3 examples/second
# [Step=3050]	Loss=0.2917	acc=0.8977	4278.5 examples/second
# [Step=3100]	Loss=0.2876	acc=0.8994	4129.5 examples/second

# %%
Nbits = 2
net = ResNetCIFAR(num_layers=20, Nbits=Nbits)
net = net.to(device)
net.load_state_dict(torch.load("net_after_global_iterative_prune.pt"))
test(net)
finetune(net, epochs=20, batch_size=256, lr=0.002, reg=1e-4)

# Load the model with best accuracy
net.load_state_dict(torch.load("quantized_net_after_finetune.pt"))
test(net)

# %% [markdown]
# ### Lab3 (e) Prune quantized model

# %%
net = ResNetCIFAR(num_layers=20, Nbits=4)
net = net.to(device)

net.load_state_dict(torch.load("pretrained_model.pt"))
best_acc = 0.
for epoch in range(20):
    print('\nEpoch: %d' % epoch)
    q=(epoch+1)*8
    
    net.train()
    # Increase model sparsity
    if epoch<10:
        global_prune_by_percentage(net, q=q)
    if epoch<9:
        finetune_after_prune(net, trainloader, criterion, optimizer,prune=False)
    else:
        finetune_after_prune(net, trainloader, criterion, optimizer)
    
    #Start the testing code.
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    num_val_steps = len(testloader)
    val_acc = correct / total
    print("Test Loss=%.4f, Test acc=%.4f" % (test_loss / (num_val_steps), val_acc))
    
    if epoch>=10:
        if val_acc > best_acc:
            best_acc = val_acc
            print("Saving...")
            torch.save(net.state_dict(), "quantized_net_after_global_iterative_prune.pt")

# %%
net.load_state_dict(torch.load("quantized_net_after_global_iterative_prune.pt"))

zeros_sum = 0
total_sum = 0
for name,layer in net.named_modules():
    if (isinstance(layer, nn.Conv2d) or isinstance(layer, nn.Linear)) and 'id_mapping' not in name:
        np_weight = layer.weight.data.cpu().numpy()
        zeros = (np_weight==0).sum()
        total = np_weight.flatten().shape[0]
        zeros_sum+=zeros
        total_sum+=total
        print('Sparsity of '+name+': '+str(zeros/total))
print('Total sparsity of: '+str(zeros_sum/total_sum))
test(net)
